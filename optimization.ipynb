# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# GRADIENT DESCENT ALGORITHM

# %%
import numpy as np
import matplotlib.pyplot as plt

def y_func(x):
    return x*x

def y_derivative(x):
    return 2*x

x = np.arange(-100, 100, 0.1)
y = y_func(x)

current_pos = (80, y_func(80))
learning_rate = 0.1

for _ in range(20):
    x_new = current_pos[0] - learning_rate*y_derivative(current_pos[0])
    y_new = y_func(x_new)
    current_pos = (x_new, y_new)
    
    plt.plot(x, y)
    plt.scatter(current_pos[0], current_pos[1], color='blue')
    plt.pause(0.001)
    plt.clf()
    
# plt.clf() is a Matplotlib function that stands for "clear figure." It is used to clear the entire current figure. This means that all the axes, labels, title, and other elements in the current figure will be removed, and you will have a clean slate to create a new plot or add new elements to the figure.In the provided code, ax.clear() is used to clear the current 3D axes after each iteration of the loop, and plt.clf() is used to clear the entire figure. However, in this case, the ax.clear() is sufficient, and you can omit the plt.clf() since you are working with a single subplot (axes) in this scenario. The ax.clear() removes the previous 3D plot from the axes, allowing the next iteration to be plotted without interference from the previous plot.

# %% [markdown]
# 3D GRADIENT DESCENT

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import display, clear_output

# Define the mathematical function for the surface
def z_function(x, y):
    return np.sin(5*x) * np.cos(5*y) / 5

# Calculate the gradient of the function at a given point (x, y)
def calc_gradient(x, y):
    return np.cos(5*x) * np.cos(5*y), -np.sin(5*x) * np.sin(5*y)

# Generate x and y values for the surface plot
x = np.arange(-1, 1, 0.05)
y = np.arange(-1, 1, 0.05)

# Create a grid of (x, y) values
X, Y = np.meshgrid(x, y)

# Calculate the initial values of the function for the surface plot
Z = z_function(X, Y)

# Set the initial position for gradient descent
current_pos = (0.7, 0.4, z_function(0.7, 0.4))

# Set the learning rate for gradient descent
learning_rate = 0.1

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(projection="3d", computed_zorder=False)

# Perform gradient descent for a specified number of iterations
for _ in range(20):
    # Calculate the gradient at the current position
    X_derivative, Y_derivative = calc_gradient(current_pos[0], current_pos[1])

    # Update the position using gradient descent
    X_new, Y_new = current_pos[0] - learning_rate * X_derivative, current_pos[1] - learning_rate * Y_derivative
    current_pos = (X_new, Y_new, z_function(X_new, Y_new))

    # Find the indices in the grid corresponding to the updated coordinates
    x_idx = np.argmin(np.abs(x - X_new))
    y_idx = np.argmin(np.abs(y - Y_new))

    # Update the Z values for the specific point in the grid
    Z[x_idx, y_idx] = z_function(X_new, Y_new)

    # Plot the surface
    ax.plot_surface(X, Y, Z, cmap="viridis")

    # Plot the current position as an orange-colored point
    ax.scatter(current_pos[0], current_pos[1], current_pos[2], color="orange", zorder=1)

    # Display the plot in the notebook
    display(fig)
    clear_output(wait=True)

    # Pause to show the plot for a short time
    plt.pause(0.01)

    # Clear the plot for the next iteration
    ax.clear()

# Close the plot at the end
plt.close(fig)


## SEE THE ANIMATION IN THE FINAL OUTPUT

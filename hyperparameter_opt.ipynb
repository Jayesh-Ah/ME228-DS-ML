# %% [markdown]
# ## Hyperparameter Tuning
#
# 1. GridSearchCV
# 2. RandomizedSearchCV
# 3. Bayesian Optimization - Automate Hyperparameter Tuning (Hyperopt)
# 4. Sequential Model Based Optimization (Tuning a scikit-learn estimator with skopt)
# 5. Optuna- Automate Hyperparameter Tuning
# 6. Genetic Algorithms (TPOT Classifier)

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
(df == 0).sum()            # Glucose, BP, Skin Thickness, Insulin, BMI can't be zero
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
df['Glucose']=np.where(df['Glucose']==0,df['Glucose'].median(),df['Glucose'])
df['BloodPressure']=np.where(df['BloodPressure']==0,df['BloodPressure'].median(),df['BloodPressure'])
df['SkinThickness']=np.where(df['SkinThickness']==0,df['SkinThickness'].median(),df['SkinThickness'])
df['Insulin']=np.where(df['Insulin']==0,df['Insulin'].median(),df['Insulin'])
df['BMI']=np.where(df['BMI']==0,df['BMI'].median(),df['BMI'])
df.head()                   # Replaced by the median values so that it is robust to outliers
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0     30.5  33.6
# 1            1     85.0           66.0           29.0     30.5  26.6
# 2            8    183.0           64.0           23.0     30.5  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#### Independent And Dependent features
X=df.drop('Outcome',axis=1)
y=df['Outcome']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier=RandomForestClassifier(n_estimators=10).fit(X_train,y_train)
prediction=rf_classifier.predict(X_test)

# %%
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
print(confusion_matrix(y_test,prediction))
print(accuracy_score(y_test,prediction))
print(classification_report(y_test,prediction))
# Out:
# [[92 15]
#  [23 24]]
# 0.7532467532467533
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83       107
#            1       0.62      0.51      0.56        47
#
#     accuracy                           0.75       154
#    macro avg       0.71      0.69      0.69       154
# weighted avg       0.74      0.75      0.75       154

# %% [markdown]
# ### Manual Hyperparameter Tuning
#
# The main parameters used by a Random Forest Classifier are:
#
# - criterion = the function used to evaluate the quality of a split.
# - max_depth = maximum number of levels allowed in each tree.
# - max_features = maximum number of features considered when splitting a node.
# - min_samples_leaf = minimum number of samples which can be stored in a tree leaf.
# - min_samples_split = minimum number of samples necessary in a node to cause node splitting.
# - n_estimators = number of trees in the ensamble.

# %%
model=RandomForestClassifier(n_estimators=300,criterion='entropy',
                             max_features='sqrt',min_samples_leaf=10,random_state=100).fit(X_train,y_train)
predictions=model.predict(X_test)
print(confusion_matrix(y_test,predictions))
print(accuracy_score(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[98  9]
#  [19 28]]
# 0.8181818181818182
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88       107
#            1       0.76      0.60      0.67        47
#
#     accuracy                           0.82       154
#    macro avg       0.80      0.76      0.77       154
# weighted avg       0.81      0.82      0.81       154

# %% [markdown]
# ### Randomized SearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 1000,10)]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10,14]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,6,8]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
              'criterion':['entropy','gini']}
print(random_grid)
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_split': [2, 5, 10, 14], 'min_samples_leaf': [1, 2, 4, 6, 8], 'criterion': ['entropy', 'gini']}

# %%
rf=RandomForestClassifier()
rf_randomcv=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,n_iter=100,cv=3,verbose=2,
                               random_state=100,n_jobs=-1)
### fit the randomized model
rf_randomcv.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=120, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=1400; total time=   2.9s
# [CV] END criterion=gini, max_depth=120, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=1400; total time=   2.9s
# [CV] END criterion=gini, max_depth=120, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=1400; total time=   2.8s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=2000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=2000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=2000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=340, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   4.2s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   1.3s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   1.3s
# [CV] END criterion=gini, max_depth=340, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   4.2s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   1.3s
# [CV] END criterion=gini, max_depth=340, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   4.3s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=2000; total time=   4.5s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1400; total time=   3.2s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=2000; total time=   4.6s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=2000; total time=   4.6s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   1.4s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   1.3s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=8, min_samples_split=14, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=8, min_samples_split=14, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=8, min_samples_split=14, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=1400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=1400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=1400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1400; total time=   3.1s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1400; total time=   3.1s
# [CV] END criterion=gini, max_depth=670, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   1.4s
# [CV] END criterion=gini, max_depth=670, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=230, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=230, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=230, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=600; total time=   1.2s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=600; total time=   1.2s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=1800; total time=   3.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=1800; total time=   3.8s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=1800; total time=   3.8s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=600; total time=   1.3s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=450, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=1000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=1000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=1000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   4.3s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   4.3s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   4.2s
# [CV] END criterion=entropy, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=1600; total time=   3.4s
# [CV] END criterion=gini, max_depth=780, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   2.7s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=1600; total time=   3.5s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=8, min_samples_split=14, n_estimators=800; total time=   0.0s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=8, min_samples_split=14, n_estimators=800; total time=   0.0s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=8, min_samples_split=14, n_estimators=800; total time=   0.0s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=1600; total time=   3.3s
# [CV] END criterion=gini, max_depth=780, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   2.7s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=   1.8s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=   1.8s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time=   1.8s
# [CV] END criterion=gini, max_depth=780, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   2.6s
# [CV] END criterion=gini, max_depth=120, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=120, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=120, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=560, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   0.0s
# [CV] END criterion=entropy, max_depth=1000, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   2.0s
# [CV] END criterion=entropy, max_depth=1000, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   1.9s
# [CV] END criterion=entropy, max_depth=1000, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time=   1.9s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   2.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   1.9s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800; total time=   1.9s
# [CV] END criterion=gini, max_depth=1000, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1200; total time=   2.6s
# [CV] END criterion=gini, max_depth=1000, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1200; total time=   2.5s
# [CV] END criterion=gini, max_depth=1000, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1200; total time=   2.5s
# [CV] END criterion=gini, max_depth=1000, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   4.4s
# [CV] END criterion=gini, max_depth=1000, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   4.2s
# [CV] END criterion=gini, max_depth=780, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=1600; total time=   3.4s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=log2, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   4.2s
# [CV] END criterion=gini, max_depth=780, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=1600; total time=   3.3s
# [CV] END criterion=gini, max_depth=780, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=1600; total time=   3.3s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=2000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=2000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1600; total time=   3.8s
# [CV] END criterion=gini, max_depth=890, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1600; total time=   3.9s
# [CV] END criterion=gini, max_depth=890, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1600; total time=   3.7s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1800; total time=   4.5s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1800; total time=   4.4s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1800; total time=   4.2s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=   4.4s
# [CV] END criterion=entropy, max_depth=780, max_features=log2, min_samples_leaf=4, min_samples_split=14, n_estimators=800; total time=   1.9s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=   4.6s
# [CV] END criterion=entropy, max_depth=450, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=1400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=1400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=auto, min_samples_leaf=6, min_samples_split=2, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=log2, min_samples_leaf=4, min_samples_split=14, n_estimators=800; total time=   1.9s
# [CV] END criterion=entropy, max_depth=780, max_features=log2, min_samples_leaf=4, min_samples_split=14, n_estimators=800; total time=   1.8s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time=   4.4s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   1.8s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   1.9s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time=   1.8s
# [CV] END criterion=gini, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1400; total time=   3.1s
# [CV] END criterion=gini, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1400; total time=   3.2s
# [CV] END criterion=gini, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1400; total time=   3.2s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=1800; total time=   3.8s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=14, n_estimators=600; total time=   1.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=14, n_estimators=600; total time=   1.4s[CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=1800; total time=   3.8s
#
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=14, n_estimators=600; total time=   1.4s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=1800; total time=   4.1s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=2000; total time=   4.4s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=2000; total time=   4.6s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1400; total time=   3.4s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=2000; total time=   4.5s
# [CV] END criterion=gini, max_depth=780, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.3s
# [CV] END criterion=gini, max_depth=780, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.3s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=340, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=340, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=780, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.5s
# [CV] END criterion=entropy, max_depth=340, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1400; total time=   3.6s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1400; total time=   3.4s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=2, min_samples_split=14, n_estimators=1000; total time=   2.2s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=   3.1s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=   3.0s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1400; total time=   3.0s
# [CV] END criterion=entropy, max_depth=780, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   1.8s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=2, min_samples_split=14, n_estimators=1000; total time=   2.4s
# [CV] END criterion=entropy, max_depth=780, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   1.8s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=2, min_samples_split=14, n_estimators=1000; total time=   2.6s
# [CV] END criterion=entropy, max_depth=780, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   1.9s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=1800; total time=   4.8s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=1800; total time=   5.1s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=1800; total time=   5.0s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.3s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.3s
# [CV] END criterion=gini, max_depth=340, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=2000; total time=   5.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.3s
# [CV] END criterion=gini, max_depth=340, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=2000; total time=   5.0s
# [CV] END criterion=gini, max_depth=340, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=2000; total time=   4.8s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1800; total time=   4.2s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1800; total time=   4.4s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1800; total time=   4.6s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   0.0s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   5.0s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   5.2s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=2000; total time=   4.9s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=   4.6s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=   4.5s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1200; total time=   2.8s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1200; total time=   2.8s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1200; total time=   2.7s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=2000; total time=   4.6s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=780, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=780, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   1.5s
# [CV] END criterion=gini, max_depth=780, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   1.4s
# [CV] END criterion=entropy, max_depth=450, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=450, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=780, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   1.3s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1600; total time=   4.0s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1600; total time=   3.9s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1600; total time=   3.9s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1800; total time=   4.3s
# [CV] END criterion=gini, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1400; total time=   2.9s
# [CV] END criterion=gini, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1400; total time=   2.8s
# [CV] END criterion=gini, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1800; total time=   4.1s
# [CV] END criterion=entropy, max_depth=780, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1800; total time=   4.1s
# [CV] END criterion=entropy, max_depth=780, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=780, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=1000, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1400; total time=   2.9s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=1, min_samples_split=14, n_estimators=1200; total time=   2.7s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=1, min_samples_split=14, n_estimators=1200; total time=   3.0s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=1400; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=1, min_samples_split=14, n_estimators=1200; total time=   2.7s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   1.1s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=400; total time=   1.1s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=8, min_samples_split=14, n_estimators=1600; total time=   3.5s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=8, min_samples_split=14, n_estimators=1600; total time=   3.4s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=8, min_samples_split=14, n_estimators=1600; total time=   3.5s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=600; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   4.4s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1400; total time=   3.0s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   4.3s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1400; total time=   3.1s
# [CV] END criterion=entropy, max_depth=120, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   4.6s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   1.2s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   1.3s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   1.3s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1400; total time=   3.2s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=1600; total time=   0.0s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=800; total time=   0.0s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=2000; total time=   0.0s
# [CV] END criterion=gini, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   2.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   4.3s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   4.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=2000; total time=   4.2s
# [CV] END criterion=gini, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   2.2s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   1.4s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   1.4s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   1.4s
# [CV] END criterion=gini, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   2.2s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=   0.0s
# [CV] END criterion=gini, max_depth=560, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=560, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=560, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=1600; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=1000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=1000; total time=   0.0s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=1000; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=1, min_samples_split=14, n_estimators=1600; total time=   2.6s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=1, min_samples_split=14, n_estimators=1600; total time=   3.1s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=1, min_samples_split=14, n_estimators=1600; total time=   3.1s
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [10, 120, 230, 340, 450,
#                                                       560, 670, 780, 890,
#                                                       1000],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 4, 6, 8],
#                                         'min_samples_split': [2, 5, 10, 14],
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000, 1200, 1400, 1600,
#                                                          1800, 2000]},
#                    random_state=100, verbose=2)

# %%
rf_randomcv.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 14,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 10,
#  'criterion': 'gini'}

# %%
rf_randomcv
# Out:
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [10, 120, 230, 340, 450,
#                                                       560, 670, 780, 890,
#                                                       1000],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 4, 6, 8],
#                                         'min_samples_split': [2, 5, 10, 14],
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000, 1200, 1400, 1600,
#                                                          1800, 2000]},
#                    random_state=100, verbose=2)

# %%
best_random_grid=rf_randomcv.best_estimator_

# %%
from sklearn.metrics import accuracy_score
y_pred=best_random_grid.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print("Accuracy Score {}".format(accuracy_score(y_test,y_pred)))
print("Classification report: {}".format(classification_report(y_test,y_pred)))
# Out:
# [[94 13]
#  [16 31]]
# Accuracy Score 0.8116883116883117
# Classification report:               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87       107
#            1       0.70      0.66      0.68        47
#
#     accuracy                           0.81       154
#    macro avg       0.78      0.77      0.77       154
# weighted avg       0.81      0.81      0.81       154

# %% [markdown]
# ### Grid SearchCV

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'criterion': [rf_randomcv.best_params_['criterion']],
    'max_depth': [rf_randomcv.best_params_['max_depth']],
    'max_features': [rf_randomcv.best_params_['max_features']],
    'min_samples_leaf': [rf_randomcv.best_params_['min_samples_leaf'], 
                         rf_randomcv.best_params_['min_samples_leaf']+2, 
                         rf_randomcv.best_params_['min_samples_leaf'] + 4],
    'min_samples_split': [rf_randomcv.best_params_['min_samples_split'] - 2,
                          rf_randomcv.best_params_['min_samples_split'] - 1,
                          rf_randomcv.best_params_['min_samples_split'], 
                          rf_randomcv.best_params_['min_samples_split'] +1,
                          rf_randomcv.best_params_['min_samples_split'] + 2],
    'n_estimators': [rf_randomcv.best_params_['n_estimators'] - 200, rf_randomcv.best_params_['n_estimators'] - 100, 
                     rf_randomcv.best_params_['n_estimators'], 
                     rf_randomcv.best_params_['n_estimators'] + 100, rf_randomcv.best_params_['n_estimators'] + 200]
}

print(param_grid)
# Out:
# {'criterion': ['gini'], 'max_depth': [10], 'max_features': ['sqrt'], 'min_samples_leaf': [1, 3, 5], 'min_samples_split': [12, 13, 14, 15, 16], 'n_estimators': [0, 100, 200, 300, 400]}

# %%
#### Fit the grid_search to the data
rf=RandomForestClassifier()
grid_search=GridSearchCV(estimator=rf,param_grid=param_grid,cv=10,n_jobs=-1,verbose=2)
grid_search.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 75 candidates, totalling 750 fits
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=100; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=300; total time=   0.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=400; total time=   1.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=   0.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time=   0.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=   1.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=   1.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=   1.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=   1.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=   1.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=0; total time=   0.0s
# ...
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=14, n_estimators=300; total time=   0.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=14, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=14, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=14, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=14, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=14, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=300; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=300; total time=   0.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=300; total time=   0.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=400; total time=   1.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=400; total time=   1.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=16, n_estimators=400; total time=   0.6s
# GridSearchCV(cv=10, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini'], 'max_depth': [10],
#                          'max_features': ['sqrt'],
#                          'min_samples_leaf': [1, 3, 5],
#                          'min_samples_split': [12, 13, 14, 15, 16],
#                          'n_estimators': [0, 100, 200, 300, 400]},
#              verbose=2)

# %%
best_grid=grid_search.best_estimator_
best_grid
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=5, min_samples_split=13,
#                        n_estimators=300)

# %%
y_pred=best_grid.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print("Accuracy Score {}".format(accuracy_score(y_test,y_pred)))
print("Classification report: {}".format(classification_report(y_test,y_pred)))
# Out:
# [[97 10]
#  [16 31]]
# Accuracy Score 0.8311688311688312
# Classification report:               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88       107
#            1       0.76      0.66      0.70        47
#
#     accuracy                           0.83       154
#    macro avg       0.81      0.78      0.79       154
# weighted avg       0.83      0.83      0.83       154

# %% [markdown]
# ## Automated Hyperparameter Tuning
# Automated Hyperparameter Tuning can be done by using techniques such as
#
# - Bayesian Optimization
# - Gradient Descent
# - Evolutionary Algorithms

# %% [markdown]
# ### Bayesian Optimization
# Bayesian optimization uses probability to find the minimum of a function. The final aim is to find the input value to a function which can gives us the lowest possible output value.It usually performs better than random,grid and manual search providing better performance in the testing phase and reduced optimization time. In Hyperopt, Bayesian Optimization can be implemented giving 3 three main parameters to the function fmin.
#
# - Objective Function = defines the loss function to minimize.
# - Domain Space = defines the range of input values to test (in Bayesian Optimization this space creates a probability distribution for each of the used Hyperparameters).
# - Optimization Algorithm = defines the search algorithm to use to select the best input values to use in each new iteration.

# %%
# !pip install hyperopt
# Out:
# Collecting hyperopt
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from hyperopt) (1.26.4)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.10/site-packages (from hyperopt) (1.13.1)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.10/site-packages (from hyperopt) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in /home/codespace/.local/lib/python3.10/site-packages (from hyperopt) (3.3)
# Collecting future (from hyperopt)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting tqdm (from hyperopt)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 597.9 kB/s eta 0:00:00a 0:00:01
# Collecting cloudpickle (from hyperopt)
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting py4j (from hyperopt)
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl.metadata (1.5 kB)
# Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.2 MB/s eta 0:00:0000:0100:01
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 10.3 MB/s eta 0:00:0000:01
# Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 4.6 MB/s eta 0:00:00ta 0:00:01
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: py4j, tqdm, future, cloudpickle, hyperopt
# Successfully installed cloudpickle-3.0.0 future-1.0.0 hyperopt-0.2.7 py4j-0.10.9.7 tqdm-4.66.4

# %%
from hyperopt import hp,fmin,tpe,STATUS_OK,Trials

# %%
# Option 1: Use a fixed number of features
feature_options_fixed = hp.quniform('max_features_fixed', 1, len(X_train.columns), 1)

# Option 2: Use a percentage of features
feature_options_ratio = hp.uniform('max_features_ratio', 0.0, 1.0)

space = {'criterion': hp.choice('criterion', ['entropy', 'gini']),
        'max_depth': hp.quniform('max_depth', 10, 100, 1),
        'max_features': hp.choice('max_features', ['sqrt','log2', None]),
        'min_samples_leaf': hp.uniform('min_samples_leaf', 0, 0.5),
        'min_samples_split' : hp.uniform ('min_samples_split', 0, 1),
        'n_estimators' : hp.choice('n_estimators', [10, 50, 300, 750, 1200,1300,1500])
    }
space
# Out:
# {'criterion': <hyperopt.pyll.base.Apply at 0x7667685f38b0>,
#  'max_depth': <hyperopt.pyll.base.Apply at 0x7667685f3b80>,
#  'max_features': <hyperopt.pyll.base.Apply at 0x7667685f2620>,
#  'min_samples_leaf': <hyperopt.pyll.base.Apply at 0x7667685f2890>,
#  'min_samples_split': <hyperopt.pyll.base.Apply at 0x7667685f27d0>,
#  'n_estimators': <hyperopt.pyll.base.Apply at 0x7667685f24a0>}

# %%
def objective(space):
    model = RandomForestClassifier(criterion = space['criterion'], 
                                    max_depth = int(space['max_depth']),  
                                    max_features = space['max_features'],
                                    min_samples_leaf = space['min_samples_leaf'],
                                    min_samples_split = space['min_samples_split'],
                                    n_estimators = space['n_estimators'], 
                                    )
    
    accuracy = cross_val_score(model, X_train, y_train, cv = 5).mean()

    # We aim to maximize accuracy, therefore we return it as a negative value
    return {'loss': -accuracy, 'status': STATUS_OK }

# %%
from sklearn.model_selection import cross_val_score
trials = Trials()
best = fmin(fn= objective,
            space= space,
            algo= tpe.suggest,
            max_evals = 80,
            trials= trials)
best
# Out:
#   0%|          | 0/80 [00:00<?, ?trial/s, best loss=?]
# 100%|██████████| 80/80 [06:20<00:00,  4.75s/trial, best loss: -0.7670798347327736]
# {'criterion': 0,
#  'max_depth': 65.0,
#  'max_features': 1,
#  'min_samples_leaf': 0.12188152692071894,
#  'min_samples_split': 0.037578978854515076,
#  'n_estimators': 2}

# %%
crit = {0: 'entropy', 1: 'gini'}
feat = {0: 'auto', 1: 'sqrt', 2: 'log2', 3: None}
est = {0: 10, 1: 50, 2: 300, 3: 750, 4: 1200,5:1300,6:1500}


print(crit[best['criterion']])
print(feat[best['max_features']])
print(est[best['n_estimators']])
# Out:
# entropy
# sqrt
# 300

# %%
best['min_samples_leaf']
# Out:
# 0.12188152692071894

# %%
trainedforest = RandomForestClassifier(criterion = crit[best['criterion']], 
                                       max_depth = int(best['max_depth']), 
                                       max_features = feat[best['max_features']], 
                                       min_samples_leaf = best['min_samples_leaf'], 
                                       min_samples_split = best['min_samples_split'], 
                                       n_estimators = est[best['n_estimators']]).fit(X_train,y_train)
predictionforest = trainedforest.predict(X_test)
print(confusion_matrix(y_test,predictionforest))
print(accuracy_score(y_test,predictionforest))
print(classification_report(y_test,predictionforest))
acc5 = accuracy_score(y_test,predictionforest)
# Out:
# [[99  8]
#  [31 16]]
# 0.7467532467532467
#               precision    recall  f1-score   support
#
#            0       0.76      0.93      0.84       107
#            1       0.67      0.34      0.45        47
#
#     accuracy                           0.75       154
#    macro avg       0.71      0.63      0.64       154
# weighted avg       0.73      0.75      0.72       154

# %% [markdown]
# ### Genetic Algorithms
# Genetic Algorithms tries to apply natural selection mechanisms to Machine Learning contexts.
#
# Let's immagine we create a population of N Machine Learning models with some predifined Hyperparameters. We can then calculate the accuracy of each model and decide to keep just half of the models (the ones that performs best). We can now generate some offsprings having similar Hyperparameters to the ones of the best models so that go get again a population of N models. At this point we can again caltulate the accuracy of each model and repeate the cycle for a defined number of generations. In this way, just the best models will survive at the end of the process.

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 1000,10)]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10,14]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,6,8]
# Create the random grid
param = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
              'criterion':['entropy','gini']}
print(param)
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_split': [2, 5, 10, 14], 'min_samples_leaf': [1, 2, 4, 6, 8], 'criterion': ['entropy', 'gini']}

# %%
# !pip install tpot
# Out:
# Collecting tpot
#   Downloading TPOT-0.12.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy>=1.16.3 in /home/codespace/.local/lib/python3.10/site-packages (from tpot) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from tpot) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.4.1 in /home/codespace/.local/lib/python3.10/site-packages (from tpot) (1.5.0)
# Collecting deap>=1.2 (from tpot)
#   Downloading deap-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting update-checker>=0.16 (from tpot)
#   Downloading update_checker-0.18.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tpot) (4.66.4)
# Collecting stopit>=1.1.1 (from tpot)
#   Downloading stopit-1.1.2.tar.gz (18 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas>=0.24.2 in /home/codespace/.local/lib/python3.10/site-packages (from tpot) (2.2.2)
# Requirement already satisfied: joblib>=0.13.2 in /home/codespace/.local/lib/python3.10/site-packages (from tpot) (1.4.2)
# Collecting xgboost>=1.1.0 (from tpot)
#   Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=0.24.2->tpot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=0.24.2->tpot) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=0.24.2->tpot) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn>=1.4.1->tpot) (3.5.0)
# Requirement already satisfied: requests>=2.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from update-checker>=0.16->tpot) (2.32.3)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->tpot) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2024.2.2)
# Downloading TPOT-0.12.2-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 857.8 kB/s eta 0:00:000:00:01
# Downloading deap-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 1.7 MB/s eta 0:00:0000:0100:01
# Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl (297.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 5.7 MB/s eta 0:00:00:00:0100:01
# Building wheels for collected packages: stopit
#   Building wheel for stopit (pyproject.toml) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11938 sha256=90c1b112d810da8b9308c0058144117d5cae9770b6d278e3dd471096987bcd2b
#   Stored in directory: /home/codespace/.cache/pip/wheels/af/f9/87/bf5b3d565c2a007b4dae9d8142dccc85a9f164e517062dd519
# Successfully built stopit
# Installing collected packages: stopit, deap, xgboost, update-checker, tpot
# Successfully installed deap-1.4.1 stopit-1.1.2 tpot-0.12.2 update-checker-0.18.0 xgboost-2.0.3

# %%
from tpot import TPOTClassifier


tpot_classifier = TPOTClassifier(generations= 5, population_size= 24, offspring_size= 12,
                                 verbosity= 2, early_stop= 12,
                                 config_dict={'sklearn.ensemble.RandomForestClassifier': param}, 
                                 cv = 4, scoring = 'accuracy')
tpot_classifier.fit(X_train,y_train)
# Out:
#
# Generation 1 - Current best internal CV score: 0.7524934216110687
#
# Generation 2 - Current best internal CV score: 0.7524934216110687
#
# Generation 3 - Current best internal CV score: 0.7524934216110687
#
# Generation 4 - Current best internal CV score: 0.7524934216110687
#
# Generation 5 - Current best internal CV score: 0.7524934216110687
#
# Best pipeline: RandomForestClassifier(input_matrix, criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=2000)
# TPOTClassifier(config_dict={'sklearn.ensemble.RandomForestClassifier': {'criterion': ['entropy',
#                                                                                       'gini'],
#                                                                         'max_depth': [10,
#                                                                                       120,
#                                                                                       230,
#                                                                                       340,
#                                                                                       450,
#                                                                                       560,
#                                                                                       670,
#                                                                                       780,
#                                                                                       890,
#                                                                                       1000],
#                                                                         'max_features': ['auto',
#                                                                                          'sqrt',
#                                                                                          'log2'],
#                                                                         'min_samples_leaf': [1,
#                                                                                              2,
#                                                                                              4,
#                                                                                              6,
#                                                                                              8],
#                                                                         'min_samples_split': [2,
#                                                                                               5,
#                                                                                               10,
#                                                                                               14],
#                                                                         'n_estimators': [200,
#                                                                                          400,
#                                                                                          600,
#                                                                                          800,
#                                                                                          1000,
#                                                                                          1200,
#                                                                                          1400,
#                                                                                          1600,
#                                                                                          1800,
#                                                                                          2000]}},
#                cv=4, early_stop=12, generations=5, offspring_size=12,
#                population_size=24, scoring='accuracy', verbosity=2)

# %%
accuracy = tpot_classifier.score(X_test, y_test)
print(accuracy)
# Out:
# 0.8181818181818182

# %% [markdown]
# ### Optimize hyperparameters of the model using Optuna
# The hyperparameters of the above algorithm are n_estimators and max_depth for which we can try different values to see if the model accuracy can be improved. The objective function is modified to accept a trial object. This trial has several methods for sampling hyperparameters. We create a study to run the hyperparameter optimization and finally read the best hyperparameters.

# %%
pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from optuna) (24.0)
# Collecting sqlalchemy>=1.3.0 (from optuna)
#   Downloading SQLAlchemy-2.0.30-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: tqdm in /usr/local/python/3.10.13/lib/python3.10/site-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /home/codespace/.local/lib/python3.10/site-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /home/codespace/.local/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (4.12.0)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.3.0->optuna)
#   Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/codespace/.local/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 2.0 MB/s eta 0:00:0000:0100:01
# Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 4.9 MB/s eta 0:00:00ta 0:00:01
# Downloading SQLAlchemy-2.0.30-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 17.8 MB/s eta 0:00:0000:0100:01
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (616 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.0/616.0 kB 14.6 MB/s eta 0:00:0000:01
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: Mako, greenlet, colorlog, sqlalchemy, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.1 colorlog-6.8.2 greenlet-3.0.3 optuna-3.6.1 sqlalchemy-2.0.30
# Note: you may need to restart the kernel to use updated packages.

# %%
import optuna
import sklearn.svm
def objective(trial):

    classifier = trial.suggest_categorical('classifier', ['RandomForest', 'SVC'])
    
    if classifier == 'RandomForest':
        n_estimators = trial.suggest_int('n_estimators', 200, 2000,10)
        max_depth = int(trial.suggest_float('max_depth', 10, 100, log=True))

        clf = sklearn.ensemble.RandomForestClassifier(
            n_estimators=n_estimators, max_depth=max_depth)
    else:
        c = trial.suggest_float('svc_c', 1e-10, 1e10, log=True)
        
        clf = sklearn.svm.SVC(C=c, gamma='auto')

    return sklearn.model_selection.cross_val_score(
        clf,X_train,y_train, n_jobs=-1, cv=3).mean()

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

trial = study.best_trial

print('Accuracy: {}'.format(trial.value))
print("Best hyperparameters: {}".format(trial.params))
# Out:
# [I 2024-06-18 13:15:30,650] A new study created in memory with name: no-name-c80e0127-475f-4467-beea-fba606e6f447
# [I 2024-06-18 13:15:37,995] Trial 0 finished with value: 0.7410250278973378 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1880, 'max_depth': 35.41530260034809}. Best is trial 0 with value: 0.7410250278973378.
# [I 2024-06-18 13:15:39,133] Trial 1 finished with value: 0.736139008448908 and parameters: {'classifier': 'RandomForest', 'n_estimators': 310, 'max_depth': 57.900575627435465}. Best is trial 0 with value: 0.7410250278973378.
# [I 2024-06-18 13:15:42,674] Trial 2 finished with value: 0.7410250278973378 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1900, 'max_depth': 34.65913262946154}. Best is trial 0 with value: 0.7410250278973378.
# [I 2024-06-18 13:15:42,710] Trial 3 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 46.94571128809454}. Best is trial 0 with value: 0.7410250278973378.
# [I 2024-06-18 13:15:42,747] Trial 4 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 2805264208.82982}. Best is trial 0 with value: 0.7410250278973378.
# [I 2024-06-18 13:15:44,615] Trial 5 finished with value: 0.7475370636059302 and parameters: {'classifier': 'RandomForest', 'n_estimators': 960, 'max_depth': 11.038800889111863}. Best is trial 5 with value: 0.7475370636059302.
# [I 2024-06-18 13:15:44,651] Trial 6 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 1.3074619511468116e-07}. Best is trial 5 with value: 0.7475370636059302.
# [I 2024-06-18 13:15:44,697] Trial 7 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 8703249616.434793}. Best is trial 5 with value: 0.7475370636059302.
# [I 2024-06-18 13:15:44,732] Trial 8 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 6.545690040612421e-08}. Best is trial 5 with value: 0.7475370636059302.
# [I 2024-06-18 13:15:47,789] Trial 9 finished with value: 0.7410329985652798 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1610, 'max_depth': 20.240318490741437}. Best is trial 5 with value: 0.7475370636059302.
# [I 2024-06-18 13:15:49,403] Trial 10 finished with value: 0.744293001753547 and parameters: {'classifier': 'RandomForest', 'n_estimators': 870, 'max_depth': 10.18930158033739}. Best is trial 5 with value: 0.7475370636059302.
# [I 2024-06-18 13:15:50,994] Trial 11 finished with value: 0.744293001753547 and parameters: {'classifier': 'RandomForest', 'n_estimators': 850, 'max_depth': 10.827225246197381}. Best is trial 5 with value: 0.7475370636059302.
# [I 2024-06-18 13:15:52,879] Trial 12 finished with value: 0.7426510441575004 and parameters: {'classifier': 'RandomForest', 'n_estimators': 970, 'max_depth': 10.855113157064155}. Best is trial 5 with value: 0.7475370636059302.
# [I 2024-06-18 13:15:54,086] Trial 13 finished with value: 0.744285031085605 and parameters: {'classifier': 'RandomForest', 'n_estimators': 630, 'max_depth': 16.28704740719945}. Best is trial 5 with value: 0.7475370636059302.
# [I 2024-06-18 13:15:56,801] Trial 14 finished with value: 0.7345209628566874 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1290, 'max_depth': 15.943246764489153}. Best is trial 5 with value: 0.7475370636059302.
# [I 2024-06-18 13:15:59,225] Trial 15 finished with value: 0.7410250278973378 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1230, 'max_depth': 89.62998569624561}. Best is trial 5 with value: 0.7475370636059302.
# [I 2024-06-18 13:16:00,247] Trial 16 finished with value: 0.7491471385302089 and parameters: {'classifier': 'RandomForest', 'n_estimators': 520, 'max_depth': 10.209830090077926}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:00,988] Trial 17 finished with value: 0.7475450342738722 and parameters: {'classifier': 'RandomForest', 'n_estimators': 390, 'max_depth': 22.98275567507432}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:01,466] Trial 18 finished with value: 0.7361230671130241 and parameters: {'classifier': 'RandomForest', 'n_estimators': 240, 'max_depth': 22.796434326873904}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:02,503] Trial 19 finished with value: 0.7459030766778256 and parameters: {'classifier': 'RandomForest', 'n_estimators': 540, 'max_depth': 45.91470960363688}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:03,498] Trial 20 finished with value: 0.7410409692332217 and parameters: {'classifier': 'RandomForest', 'n_estimators': 530, 'max_depth': 26.8559567814492}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:04,950] Trial 21 finished with value: 0.7377650247090707 and parameters: {'classifier': 'RandomForest', 'n_estimators': 730, 'max_depth': 14.0859970173671}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:05,626] Trial 22 finished with value: 0.736154949784792 and parameters: {'classifier': 'RandomForest', 'n_estimators': 350, 'max_depth': 13.570420337033203}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:07,692] Trial 23 finished with value: 0.7426590148254424 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1100, 'max_depth': 17.917859494758552}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:08,554] Trial 24 finished with value: 0.7475530049418141 and parameters: {'classifier': 'RandomForest', 'n_estimators': 430, 'max_depth': 13.15987587774162}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:09,381] Trial 25 finished with value: 0.7426510441575004 and parameters: {'classifier': 'RandomForest', 'n_estimators': 430, 'max_depth': 23.57840436071449}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:09,420] Trial 26 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 1.3213980785630666}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:09,862] Trial 27 finished with value: 0.7426351028216165 and parameters: {'classifier': 'RandomForest', 'n_estimators': 200, 'max_depth': 13.352316122691144}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:11,150] Trial 28 finished with value: 0.7458871353419417 and parameters: {'classifier': 'RandomForest', 'n_estimators': 670, 'max_depth': 28.62577935999902}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:12,012] Trial 29 finished with value: 0.7377889367128966 and parameters: {'classifier': 'RandomForest', 'n_estimators': 440, 'max_depth': 18.58606763567907}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:13,418] Trial 30 finished with value: 0.7442770604176631 and parameters: {'classifier': 'RandomForest', 'n_estimators': 750, 'max_depth': 12.630960365445455}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:14,351] Trial 31 finished with value: 0.7491471385302089 and parameters: {'classifier': 'RandomForest', 'n_estimators': 500, 'max_depth': 10.05364512178041}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:15,358] Trial 32 finished with value: 0.7475450342738722 and parameters: {'classifier': 'RandomForest', 'n_estimators': 500, 'max_depth': 10.046481585678999}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:16,028] Trial 33 finished with value: 0.7410329985652798 and parameters: {'classifier': 'RandomForest', 'n_estimators': 340, 'max_depth': 12.500652516095256}. Best is trial 16 with value: 0.7491471385302089.
# [I 2024-06-18 13:16:17,177] Trial 34 finished with value: 0.75242308305436 and parameters: {'classifier': 'RandomForest', 'n_estimators': 600, 'max_depth': 15.421707110722618}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:18,303] Trial 35 finished with value: 0.7459110473457676 and parameters: {'classifier': 'RandomForest', 'n_estimators': 600, 'max_depth': 15.34024814273925}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:18,338] Trial 36 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 1.0925632275518696e-10}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:21,463] Trial 37 finished with value: 0.7426351028216165 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1690, 'max_depth': 11.844475830719439}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:21,502] Trial 38 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 8220.927624024329}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:22,927] Trial 39 finished with value: 0.7393990116371753 and parameters: {'classifier': 'RandomForest', 'n_estimators': 730, 'max_depth': 14.557434862702248}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:23,447] Trial 40 finished with value: 0.7410250278973378 and parameters: {'classifier': 'RandomForest', 'n_estimators': 270, 'max_depth': 40.49201632184877}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:24,198] Trial 41 finished with value: 0.7491551091981509 and parameters: {'classifier': 'RandomForest', 'n_estimators': 400, 'max_depth': 20.30101199232961}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:25,163] Trial 42 finished with value: 0.73614697911685 and parameters: {'classifier': 'RandomForest', 'n_estimators': 480, 'max_depth': 17.523157922812498}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:26,314] Trial 43 finished with value: 0.7459030766778256 and parameters: {'classifier': 'RandomForest', 'n_estimators': 600, 'max_depth': 11.991677923362344}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:27,066] Trial 44 finished with value: 0.7459030766778256 and parameters: {'classifier': 'RandomForest', 'n_estimators': 340, 'max_depth': 19.15038821580606}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:27,105] Trial 45 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 0.0006158670550278445}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:28,105] Trial 46 finished with value: 0.7377729953770126 and parameters: {'classifier': 'RandomForest', 'n_estimators': 540, 'max_depth': 11.71054996018807}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:29,708] Trial 47 finished with value: 0.7393990116371753 and parameters: {'classifier': 'RandomForest', 'n_estimators': 850, 'max_depth': 14.793161572061974}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:30,528] Trial 48 finished with value: 0.7475370636059302 and parameters: {'classifier': 'RandomForest', 'n_estimators': 420, 'max_depth': 10.283466455123163}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:30,567] Trial 49 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 75801.52599209268}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:31,117] Trial 50 finished with value: 0.744285031085605 and parameters: {'classifier': 'RandomForest', 'n_estimators': 280, 'max_depth': 20.875261262645342}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:31,895] Trial 51 finished with value: 0.7410329985652798 and parameters: {'classifier': 'RandomForest', 'n_estimators': 400, 'max_depth': 23.946711556270937}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:33,182] Trial 52 finished with value: 0.7410170572293958 and parameters: {'classifier': 'RandomForest', 'n_estimators': 670, 'max_depth': 20.540995580638853}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:33,903] Trial 53 finished with value: 0.7459110473457676 and parameters: {'classifier': 'RandomForest', 'n_estimators': 360, 'max_depth': 16.620837522559256}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:34,985] Trial 54 finished with value: 0.7442770604176631 and parameters: {'classifier': 'RandomForest', 'n_estimators': 570, 'max_depth': 11.122971636832059}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:36,818] Trial 55 finished with value: 0.7410329985652798 and parameters: {'classifier': 'RandomForest', 'n_estimators': 960, 'max_depth': 31.183713242214335}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:37,773] Trial 56 finished with value: 0.7377729953770126 and parameters: {'classifier': 'RandomForest', 'n_estimators': 470, 'max_depth': 26.401429940849344}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:38,191] Trial 57 finished with value: 0.7393910409692332 and parameters: {'classifier': 'RandomForest', 'n_estimators': 210, 'max_depth': 13.1273284212595}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:39,694] Trial 58 finished with value: 0.7410250278973378 and parameters: {'classifier': 'RandomForest', 'n_estimators': 810, 'max_depth': 92.0833742686328}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:42,098] Trial 59 finished with value: 0.7426510441575004 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1300, 'max_depth': 68.1537339899283}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:43,386] Trial 60 finished with value: 0.7345129921887454 and parameters: {'classifier': 'RandomForest', 'n_estimators': 650, 'max_depth': 21.330159787724572}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:44,371] Trial 61 finished with value: 0.7394069823051171 and parameters: {'classifier': 'RandomForest', 'n_estimators': 500, 'max_depth': 10.14599913857046}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:45,325] Trial 62 finished with value: 0.7459190180137095 and parameters: {'classifier': 'RandomForest', 'n_estimators': 500, 'max_depth': 10.14967616908159}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:45,938] Trial 63 finished with value: 0.7459110473457676 and parameters: {'classifier': 'RandomForest', 'n_estimators': 290, 'max_depth': 11.095583897021319}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:46,708] Trial 64 finished with value: 0.7410250278973378 and parameters: {'classifier': 'RandomForest', 'n_estimators': 400, 'max_depth': 13.753354076785802}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:47,833] Trial 65 finished with value: 0.7345050215208034 and parameters: {'classifier': 'RandomForest', 'n_estimators': 590, 'max_depth': 11.08094669932607}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:48,572] Trial 66 finished with value: 0.7393910409692332 and parameters: {'classifier': 'RandomForest', 'n_estimators': 370, 'max_depth': 15.715685014462295}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:48,612] Trial 67 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 0.0003052252057796924}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:49,502] Trial 68 finished with value: 0.7426510441575004 and parameters: {'classifier': 'RandomForest', 'n_estimators': 470, 'max_depth': 10.008242217477115}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:50,582] Trial 69 finished with value: 0.7459030766778256 and parameters: {'classifier': 'RandomForest', 'n_estimators': 540, 'max_depth': 12.829350869035812}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:52,009] Trial 70 finished with value: 0.7475290929379882 and parameters: {'classifier': 'RandomForest', 'n_estimators': 760, 'max_depth': 11.95352647378636}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:53,849] Trial 71 finished with value: 0.744293001753547 and parameters: {'classifier': 'RandomForest', 'n_estimators': 960, 'max_depth': 11.386387955415808}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:56,185] Trial 72 finished with value: 0.7426510441575004 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1060, 'max_depth': 14.268225591604207}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:57,545] Trial 73 finished with value: 0.7377809660449546 and parameters: {'classifier': 'RandomForest', 'n_estimators': 680, 'max_depth': 17.07702175815764}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:16:58,165] Trial 74 finished with value: 0.7426430734895585 and parameters: {'classifier': 'RandomForest', 'n_estimators': 320, 'max_depth': 12.476976081761913}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:00,760] Trial 75 finished with value: 0.7491630798660928 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1350, 'max_depth': 10.820614333759803}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:03,370] Trial 76 finished with value: 0.7426510441575004 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1430, 'max_depth': 10.61954576819386}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:03,410] Trial 77 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 428800.9549190202}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:06,455] Trial 78 finished with value: 0.7459110473457676 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1550, 'max_depth': 35.92061460888459}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:09,107] Trial 79 finished with value: 0.7426510441575004 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1410, 'max_depth': 13.426237501177456}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:11,388] Trial 80 finished with value: 0.7393990116371753 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1170, 'max_depth': 15.450837446457937}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:14,753] Trial 81 finished with value: 0.744285031085605 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1800, 'max_depth': 10.964827397820365}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:15,580] Trial 82 finished with value: 0.7394069823051171 and parameters: {'classifier': 'RandomForest', 'n_estimators': 430, 'max_depth': 12.078254840610077}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:17,390] Trial 83 finished with value: 0.7410250278973378 and parameters: {'classifier': 'RandomForest', 'n_estimators': 910, 'max_depth': 11.583428940218408}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:19,309] Trial 84 finished with value: 0.7459110473457676 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1040, 'max_depth': 10.707463820407556}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:20,351] Trial 85 finished with value: 0.7475290929379882 and parameters: {'classifier': 'RandomForest', 'n_estimators': 550, 'max_depth': 25.425123922564243}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:20,879] Trial 86 finished with value: 0.7394069823051171 and parameters: {'classifier': 'RandomForest', 'n_estimators': 250, 'max_depth': 18.38055083031072}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:23,139] Trial 87 finished with value: 0.7394069823051171 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1200, 'max_depth': 12.605766953089377}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:23,180] Trial 88 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 0.0011832487829263694}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:25,577] Trial 89 finished with value: 0.7410250278973378 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1300, 'max_depth': 22.58937174799012}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:26,353] Trial 90 finished with value: 0.7394069823051171 and parameters: {'classifier': 'RandomForest', 'n_estimators': 380, 'max_depth': 29.419561153925343}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:27,268] Trial 91 finished with value: 0.7426430734895585 and parameters: {'classifier': 'RandomForest', 'n_estimators': 430, 'max_depth': 10.03821381773867}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:28,395] Trial 92 finished with value: 0.7475370636059302 and parameters: {'classifier': 'RandomForest', 'n_estimators': 610, 'max_depth': 10.605491610044428}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:29,350] Trial 93 finished with value: 0.7491630798660928 and parameters: {'classifier': 'RandomForest', 'n_estimators': 510, 'max_depth': 11.7828299686802}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:30,308] Trial 94 finished with value: 0.7393910409692332 and parameters: {'classifier': 'RandomForest', 'n_estimators': 510, 'max_depth': 14.290568462870056}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:31,206] Trial 95 finished with value: 0.7377729953770126 and parameters: {'classifier': 'RandomForest', 'n_estimators': 460, 'max_depth': 11.868577986302991}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:32,532] Trial 96 finished with value: 0.7345129921887454 and parameters: {'classifier': 'RandomForest', 'n_estimators': 700, 'max_depth': 13.204451056221618}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:33,744] Trial 97 finished with value: 0.7459030766778256 and parameters: {'classifier': 'RandomForest', 'n_estimators': 630, 'max_depth': 19.486266718471267}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:34,376] Trial 98 finished with value: 0.7393830703012912 and parameters: {'classifier': 'RandomForest', 'n_estimators': 320, 'max_depth': 12.259864853762183}. Best is trial 34 with value: 0.75242308305436.
# [I 2024-06-18 13:17:35,423] Trial 99 finished with value: 0.7442690897497211 and parameters: {'classifier': 'RandomForest', 'n_estimators': 560, 'max_depth': 11.409098245555963}. Best is trial 34 with value: 0.75242308305436.
# Accuracy: 0.75242308305436
# Best hyperparameters: {'classifier': 'RandomForest', 'n_estimators': 600, 'max_depth': 15.421707110722618}

# %%
trial
# Out:
# FrozenTrial(number=34, state=TrialState.COMPLETE, values=[0.75242308305436], datetime_start=datetime.datetime(2024, 6, 18, 13, 16, 16, 28896), datetime_complete=datetime.datetime(2024, 6, 18, 13, 16, 17, 176814), params={'classifier': 'RandomForest', 'n_estimators': 600, 'max_depth': 15.421707110722618}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'classifier': CategoricalDistribution(choices=('RandomForest', 'SVC')), 'n_estimators': IntDistribution(high=2000, log=False, low=200, step=10), 'max_depth': FloatDistribution(high=100.0, log=True, low=10.0, step=None)}, trial_id=34, value=None)

# %%
study.best_params
# Out:
# {'classifier': 'RandomForest',
#  'n_estimators': 600,
#  'max_depth': 15.421707110722618}

# %%
rf=RandomForestClassifier(n_estimators=330,max_depth=30)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=30, n_estimators=330)

# %%
y_pred=rf.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[94 13]
#  [16 31]]
# 0.8116883116883117
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87       107
#            1       0.70      0.66      0.68        47
#
#     accuracy                           0.81       154
#    macro avg       0.78      0.77      0.77       154
# weighted avg       0.81      0.81      0.81       154
